# %%
from packages.chd import Dictionary, Character, convert_pronunciations, convert_to_pleco_syntax
import json
from pathlib import Path 


def load_json(path, default_dir):
    path=path if default_dir==None else Path(default_dir)/path
    with open(path, "r") as f:
        settings = json.load(f)
    return settings
categories=load_json('dictionary_categories.json','/home/selina/Applications/MyApps/ChineseDictionary/appdata/defaults')
categories=categories['categories']

# %%
d=Dictionary('Test')
d.read('/media/selina/SHARE/MyProjects/Pleco/dictionaries/MCD/MCD.jsonl',file_format='jsonl',categories=categories)
d.read('/media/selina/SHARE/MyProjects/Pleco/dictionaries/MCD/MCD.jsonl',file_format='jsonl',categories={'german':list,'english':list})

c=d[0]
c.info()

print(c.to_pleco_entry(template='/home/selina/Applications/MyApps/ChineseDictionary/appdata/templates/pleco_template.chd'))
# Out:
# german           - acht
# english          - eight
# simple           八
# traditional      八
# pronunciation    ba1
# 八[八]	ba1	1A0AENG ◼ eightGER ◼ acht

# %%
# links = {
#     '(八, 八, ba1)': ['https://img.zdic.net/zy/jiaguwen/41_E390.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/786.svg'], 
#     '(勹, , bao1)': ['https://img.zdic.net/zy/jiaguwen/44_E23A.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/6563.svg'], 
#     '(贝, 貝, bei4)': ['https://img.zdic.net/zy/jinwen/32_ECA7.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/4505.svg'], 
#     '(冫, 冫, bing1)': None, 
#     '(艸, 艸, cao3)': None, 
#     '(艹, 艹, cao3)': None, 
#     '(屮, , che4)': ['', 'https://img.zdic.net/zy/jiaguwen/41_E27A.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/275.svg'], 
#     '(虫, 蟲, chong2)': ['https://img.zdic.net/zy/jinwen/33_F7C4.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/9838.svg'], 
#     '(辶, 辶, chuo4)': ['https://img.zdic.net/zy/jiaguwen/41_E86A.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/1205.svg'], 
#     '(寸, , cun4)': ['', 'https://img.zdic.net/zy/qinwenzi/71_E327.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/2257.svg'], 
#     '(大, , da4)': ['', 'https://img.zdic.net/zy/jiaguwen/43_E61A.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/7451.svg'], 
#     '(刀, , dao1)': ['', 'https://img.zdic.net/zy/jiaguwen/42_E23E.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/3131.svg'], 
#     '(刂, , dao1)': None, 
#     '(儿, 兒, er2)': ['https://img.zdic.net/zy/jinwen/33_E402.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/6186.svg'], 
#     '(非, 非, fei1)': ['https://img.zdic.net/zy/jiaguwen/45_EBFF.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/8642.svg'], 
#     '(阜, 阜, fu4)': ['https://img.zdic.net/zy/jiaguwen/43_F49C.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/10779.svg'], 
#     '(阝, 阝, fu4)': None, 
#     '(干, 干, gan1)': ['https://img.zdic.net/zy/jiaguwen/41_EBA0.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/1606.svg'], 
#     '(干, 乾, gan1)': ['https://img.zdic.net/zy/qinwenzi/71_EEAD.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/10922.svg'], 
#     '(干, 幹, gan4)': ['https://img.zdic.net/zy/qinwenzi/71_E5FA.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/4158.svg'], 
#     '(高, 高, gao1)': ['https://img.zdic.net/zy/jinwen/32_E803.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/3810.svg'], 
#     '(广, 廣, guang3)': ['https://img.zdic.net/zy/jinwen/33_E753.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/6719.svg'], 
#     '(丨, 丨, gun3)': None, 
#     '(禾, , he2)': ['', 'https://img.zdic.net/zy/jiaguwen/42_F0C2.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/4982.svg'], 
#     '(火, 火, huo3)': ['https://img.zdic.net/zy/jiaguwen/43_E514.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/7245.svg'], 
#     '(灬, 灬, huo3)': None, 
#     '(几, 几, ji1)': ['https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/10616.svg', 'https://img.zdic.net/zy/lishu/94_E8E5.svg'], 
#     '(几, 幾, ji3)': ['https://img.zdic.net/xz/swdz/5E7E_1711.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/10616.svg', 'https://img.zdic.net/zy/jinwen/31_F702.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/2852.svg'], 
#     '(见, 見, jian4)': ['https://img.zdic.net/zy/jinwen/33_E454.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/6207.svg'], 
#     '(冂, 冂, jiong1)': None, 
#     '(亅, 亅, jue2)': None, 
#     '(口, , kou3)': ['', 'https://img.zdic.net/zy/jiaguwen/41_E513.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/866.svg'], 
#     '(里, 里, li3)': ['https://img.zdic.net/zy/jinwen/34_E07F.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/10291.svg'], 
#     '(茻, 茻, mang3)': None, 
#     '(门, 門, men2)': ['https://img.zdic.net/zy/jiaguwen/43_EBFE.svg', 'https://img.zdic.net/zy/xiaozhuan/27_9580.svg'], 
#     '(米, 米, mi3)': ['https://img.zdic.net/zy/jiaguwen/42_F184.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/5099.svg'], 
#     '(冖, 冖, mi4)': None, 
#     '(宀, , mian2)': None, 
#     '(木, , mu4)': ['', 'https://img.zdic.net/zy/jiaguwen/42_EA67.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/3935.svg'], 
#     '(目, , mu4)': ['', 'https://img.zdic.net/zy/jinwen/31_F379.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/2389.svg'], 
#     '(女, , nü3)': ['', 'https://img.zdic.net/zy/jiaguwen/43_EC67.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/9092.svg'], 
#     '(丿, 丿, pie3)': None, 
#     '(气, 氣, qi4)': ['https://img.zdic.net/zy/jiaguwen/41_E24A.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/262.svg'], 
#     '(人, , ren2)': ['', 'https://img.zdic.net/zy/jiaguwen/42_F47D.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/5636.svg'], 
#     '(亻, , ren2)': None, 
#     '(日, , ri4)': ['', 'https://img.zdic.net/zy/jiaguwen/42_ED55.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/4767.svg'], 
#     '(肉, 肉, rou4)': ['https://img.zdic.net/zy/chuwenzi/52_EE88.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/2961.svg'], 
#     '(入, 入, ru4)': ['https://img.zdic.net/zy/jiaguwen/42_E7C4.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/3766.svg'], 
#     '(山, , shan1)': ['', 'https://img.zdic.net/zy/jiaguwen/43_E511.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/6623.svg'], 
#     '(生, , sheng1)': ['', 'https://img.zdic.net/zy/jiaguwen/42_EC57.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/4438.svg'], 
#     '(食, 食, shi2)': ['https://img.zdic.net/zy/jiaguwen/42_E760.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/3670.svg'], 
#     '(饣, 飠, shi2)': None, 
#     '(水, , shui3)': ['', 'https://img.zdic.net/zy/jiaguwen/43_E7BE.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/7870.svg'], 
#     '(氵, , shui3)': None, 
#     '(巳, 巳, si4)': ['https://img.zdic.net/zy/jiaguwen/44_E052.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/10993.svg'], 
#     '(冂, 冂, tang2)': None, 
#     '(田, , tian2)': ['', 'https://img.zdic.net/zy/jiaguwen/43_F314.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/10295.svg'], 
#     '(亠, 亠, tou2)': None, 
#     '(王, 王, wang2)': ['https://img.zdic.net/zy/jinwen/31_E180.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/98.svg'], 
#     '(囗, , wei2)': ['', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/4472.svg'], 
#     '(文, , wen2)': ['', 'https://img.zdic.net/zy/jiaguwen/43_E051.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/6478.svg'], 
#     '(夕, , xi1)': ['', 'https://img.zdic.net/zy/jiaguwen/42_EF51.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/4925.svg'], 
#     '(小, , xiao3)': ['', 'https://img.zdic.net/zy/jinwen/31_E368.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/783.svg'], 
#     '(, , xin1)': None, 
#     '(心, , xin1)': ['', 'https://img.zdic.net/zy/jiaguwen/42_ECBF.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/7570.svg'], 
#     '(忄, , xin1)': None, 
#     '(言, 言, yan2)': ['https://img.zdic.net/zy/jiaguwen/41_EC90.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/1643.svg'], 
#     '(讠, 訁, yan2)': None, 
#     '(广, , yan3)': None, 
#     '(一, , yi1)': ['', 'https://img.zdic.net/zy/jinwen/31_E000.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/0.svg'], 
#     '(乙, 乙, yi3)': ['https://img.zdic.net/zy/jiaguwen/43_F620.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/10921.svg'], 
#     '(阝, 阝, yi4)': None, 
#     '(又, 又, you4)': ['https://img.zdic.net/zy/jinwen/31_EEC8.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/2149.svg'], 
#     '(玉, , yu4)': ['', 'https://img.zdic.net/zy/jiaguwen/41_E21A.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/102.svg'], 
#     '(元, 元, yuan2)': ['https://img.zdic.net/zy/jiaguwen/41_E017.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/2.svg'], 
#     '(月, , yue4)': ['', 'https://img.zdic.net/zy/jiaguwen/42_EEA1.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/4903.svg'], 
#     '(丶, 丶, zhu3)': None, 
#     '(子, , zi3)': ['', 'https://img.zdic.net/zy/jinwen/34_E87C.svg', 'https://ziphoenicia-1300189285.cos.ap-shanghai.myqcloud.com/swjz/10952.svg'], 
#     '(子, 子, zi5)': None}
