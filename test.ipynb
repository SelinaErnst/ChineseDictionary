# %%
from packages.pleco import dictionary

# %%
d=dictionary('Test')
d.read('/media/selina/SHARE/MyProjects/Pleco/mcd.txt',file_format='pleco')
# Out:
# WARNING: entry number (1) does not have proper headers.
# WARNING: entry number (2) does not have proper headers.
# True

# %%
print(d[0:2])
# Out:
# 0. character: 八, 八, ba1
# 1. character: 勹, , bao1

# %%
print(d['干'] + d['子'])
# Out:
# 0. character: 干, 干, gan1
# 1. character: 干, 乾, gan1
# 2. character: 干, 幹, gan4
# 3. character: 子, , zi3
# 4. character: 子, 子, zi5
